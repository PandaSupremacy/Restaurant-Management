# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("ingredients v1.csv")
dataset
# Out:
#                         id                  asins          brand  \
# 0     AVphBRHOilAPnD_x0OrE             B00HXST15C  Simon Fischer
# 1     AVpfNFy1LJeJML434ma2  B008VT0W8C,B0092F8OJ8      McCormick
# 2     AVpgT49VLJeJML43MJEz             B00CHTWZ2S     Jolly Time
# 3     AVphYgnzLJeJML43aPp2             B002JJYNVW          Ziyad
# 4     AVpfiMykilAPnD_xdedK                    NaN           Hero
# ...                    ...                    ...            ...
# 9994  AVpfVL3ailAPnD_xZyHc  B00BHNV8N2,B06XC7GXCD       Wright's
# 9995  AVpgK5BZilAPnD_xofxu             B00HZO4YYW     Eden Foods
# 9996  AV00srHj-jtxr-f30m1M  B01FRJ0XKA,B01IV1D1VY    Happy Belly
# 9997  AVpfmY4RLJeJML43ANr-  B000PWIR7Q,B005ER1C6U         Quaker
# 9998  AVpe-j33LJeJML43zpy-             B001EO5JUC       Weetabix
#
#                                              categories             dateAdded  \
# 0                   Grocery & Gourmet Food,Food,Grocery  2017-01-07T20:13:17Z
# ...

# %%
dataset['features.key']
# Out:
# 0       Ingredients
# 1       Ingredients
# 2       Ingredients
# 3       Ingredients
# 4       Ingredients
#            ...
# 9994    Ingredients
# 9995    Ingredients
# 9996    Ingredients
# 9997    Ingredients
# 9998    Ingredients
# Name: features.key, Length: 9999, dtype: object

# %%
dataset.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'dateAdded', 'dateUpdated', 'ean',
#        'features.key', 'features.value', 'manufacturer', 'manufacturerNumber',
#        'name', 'sizes', 'upc', 'weight'],
#       dtype='object')

# %%
dataset['features.key']
# Out:
# 0       Ingredients
# 1       Ingredients
# 2       Ingredients
# 3       Ingredients
# 4       Ingredients
#            ...
# 9994    Ingredients
# 9995    Ingredients
# 9996    Ingredients
# 9997    Ingredients
# 9998    Ingredients
# Name: features.key, Length: 9999, dtype: object

# %%
featurelist=dataset['features.key'].unique()
feature = dataset['features.key']

# %%
featurelist[2]
# Out:
# 'Contains wheat and soy ingredients.'

# %%
rno = {}
for i in featurelist[2:]:
    rno[i] = []
    for j in range(len(feature)):
        if feature[j]==i:
            
            rno[i].append(j+1)
rno
# Out:
# {'Contains wheat and soy ingredients.': [1294, 2296, 3889, 3993, 7269, 9257],
#  '[Ingredients]': [1353, 8126],
#  'Contains wheat, milk, and soy ingredients.': [2072],
#  'Contains peanut, milk and soy ingredients.': [2075],
#  'Contains wheat ingredients.': [2120, 2284, 5790],
#  'Contains wheat ingredients.This product is manufactured on equipment that processes products containing eggs.': [2167,
#   8768,
#   9683,
#   9760],
#  'Contains wheat, milk and soy ingredients.': [2287,
#   4276,
#   4983,
#   5244,
#   5610,
#   5638,
#   7902,
#   9314,
#   9458],
#  'Contains wheat, milk.We know that allergen information is important to parents. That is why we clearly label all ingredients on our side panel. Call us if you have questions.': [2303],
#  'Contains wheat Ingredients': [2663],
#  'Contains cod and soy Ingredients.': [2922],
#  'Main Ingredients': [2978, 8032],
#  'Contains no msg, Skinless with rib meat, No preservatives, All natural Ingredients': [3072],
# ...

# %%
feature[rno['Contains wheat ingredients.'][0]-1]
# Out:
# 'Contains wheat ingredients.'

# %%
dataset.loc[dataset["features.value"]=='Servings Per Container 4NutrientAmount per Serving Daily ValueCalories30160Calories from Fat0160Total Fat0g0Saturated Fat0g0Trans Fat0g160Cholesterol0mg0Sodium0mg0Potassium135mg4Total Carbohydrate7g2Dietary Fiber1g4Sugars5g160Proteinlt1g160Vitamin A1604Vitamin C16050Calcium1600Iron1602']
# Out:
# Empty DataFrame
# Columns: [id, asins, brand, categories, dateAdded, dateUpdated, ean, features.key, features.value, manufacturer, manufacturerNumber, name, sizes, upc, weight]
# Index: []

# %%
uniset = []
for i in list(dataset["features.value"]):
    
    a = list(str(i).split(","))
    
    uniset.extend(a)
    
uniset = set(uniset)
len(uniset)
uniset
# Out:
# {'',
#  'natural evaporated cane sugar',
#  'Guar Gum. Contains Milk And Wheat Ingredients; May Contain Almond',
#  'Yogurt (Cultured Grade A Non Fat Milk',
#  'Lemon Verbena',
#  'Dutch Cocoa (processed with Alkali)',
#  'Freeze Dried Raspberry Powder',
#  ' sweet potato',
#  'Dairy And Soy.',
#  ' Bay Leaf)',
#  'Monoglycerides (Emulsifier)',
#  'Vitamin B6(Riboflavin)',
#  ' natural and artificial flavors. May also contain: artificial color Red 3 and Red 40.',
#  ' Fennel Seed)',
#  'an amazing thing happens. A complete protein is created that closely parallels the protein found in milk and eggs. In fact',
#  'Soy Sauce Powder (Soy Sauce [Fermented Soybeans And Salt]',
#  'Tinospora cordifolia (stem)',
#  ' Organic Soybeans',
#  ' Strawberry Flavored Fruit Pieces (Sugar',
#  ' xantham gum',
#  'Emulsifers (Sucrose Fatty Acid Esters',
#  'Organic Chipotle Pepper',
#  'Artificial Flavor. Contains: Milk',
#  ' Total Carb. 8g (2.6 DV) Fiber 0g (0.DV)',
#  'and Beta Carotene.',
# ...

# %%
df3 = pd.DataFrame(uniset)

# %%
df3.to_excel("ingredients.xlsx")

# %%
prepositions = pd.read_excel("prepositions.xlsx")

# %%
prepositions
# Out:
#     Unnamed: 0  prepos
# 0          0.0  aboard
# 1          1.0   about
# 2          2.0   above
# 3          3.0  across
# 4          4.0   after
# ..         ...     ...
# 72        72.0     the
# 73         NaN     And
# 74         NaN     and
# 75         NaN      of
# 76         NaN     for
#
# [77 rows x 2 columns]

# %%
prepositions.dropna(inplace=True)

# %%
prepositions.to_excel("prepositions.xlsx")

# %%
prep = pd.read_excel("prepositions.xlsx")

# %%
prep.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'prepos'], dtype='object')

# %%
preply = prep["prepos"]
preply
# Out:
# 0      aboard
# 1       about
# 2       above
# 3      across
# 4       after
#        ...
# 68     within
# 69    without
# 70         is
# 71         or
# 72        the
# Name: prepos, Length: 73, dtype: object

# %%
lis = []
finallis = []
for i in df3[0]:
    
    for j in list(str(i).split()):
        if str(j) not in preply[1]:
            lis.append(j)
    print(lis,"@@@")
    #print(" ".join(lis))
    finallis.append(" ".join(lis))
    lis = []
finallis
# Out:
# [] @@@
# ['natural', 'evaporated', 'cane', 'sugar'] @@@
# ['Guar', 'Gum.', 'Contains', 'Milk', 'And', 'Wheat', 'Ingredients;', 'May', 'Contain', 'Almond'] @@@
# ['Yogurt', '(Cultured', 'Grade', 'A', 'Non', 'Fat', 'Milk'] @@@
# ['Lemon', 'Verbena'] @@@
# ['Dutch', 'Cocoa', '(processed', 'with', 'Alkali)'] @@@
# ['Freeze', 'Dried', 'Raspberry', 'Powder'] @@@
# ['sweet', 'potato'] @@@
# ['Dairy', 'And', 'Soy.'] @@@
# ['Bay', 'Leaf)'] @@@
# ['Monoglycerides', '(Emulsifier)'] @@@
# ['Vitamin', 'B6(Riboflavin)'] @@@
# ['natural', 'and', 'artificial', 'flavors.', 'May', 'also', 'contain:', 'artificial', 'color', 'Red', '3', 'and', 'Red', '40.'] @@@
# ['Fennel', 'Seed)'] @@@
# ['an', 'amazing', 'thing', 'happens.', 'A', 'complete', 'protein', 'is', 'created', 'that', 'closely', 'parallels', 'the', 'protein', 'found', 'in', 'milk', 'and', 'eggs.', 'In', 'fact'] @@@
# ['Soy', 'Sauce', 'Powder', '(Soy', 'Sauce', '[Fermented', 'Soybeans', 'And', 'Salt]'] @@@
# ...

# %%
df3[0]
# Out:
# 0
# 1                            natural evaporated cane sugar
# 2        Guar Gum. Contains Milk And Wheat Ingredients;...
# 3                    Yogurt (Cultured Grade A Non Fat Milk
# 4                                            Lemon Verbena
#                                ...
# 37322                                           Vitamins A
# 37323                   CONTAINS LESS THAN 2 OF CORNSTARCH
# 37324      Vegetable Oils (palm kernel palm canola peanut)
# 37325                                    roasted hazelnuts
# 37326                   Contains Less than 2% of: Beef Fat
# Name: 0, Length: 37327, dtype: object

# %%
import numpy as np

data = np.load('simplified-recipes-1M.npz',allow_pickle=True)

# %%
print(data.files)
# Out:
# ['ingredients', 'recipes']

# %%
data['ingredients']
# Out:
# array(['salt', 'pepper', 'butter', ..., 'watercress leaves',
#        'emerils essence', 'corn flakes cereal'], dtype='<U39')

# %%
dictdf = {}
for i in

# %%
data['recipes']
# Out:
# array([array([ 233, 2754,   42,  120,  560,  345,  150, 2081,   12,   21],
#              dtype=int64)                                                 ,
#        array([ 198,  249,    2,  194, 1884,  791,  965,  423,   53,   48,  798,
#                 31,  362, 1031,   94,   26,    8], dtype=int64)                ,
#        array([ 328,  263,   62,   46,  445,   55, 1196,   82,  664,    3,  602,
#                 10,    7,    6,    1,  128,   61,  141,    0,  262,  140,  655,
#                 21,    8,   23,   84], dtype=int64)                            ,
#        ...,
#        array([  72,  155, 1603,  402,    3,   79,  330,   76,    6, 1102,   60,
#                 44,   58], dtype=int64)                                        ,
#        array([ 28,   2, 247,  47,   0,   4, 348,   8], dtype=int64),
#        array([  72,  208,   89,    2, 1491, 1725,   19,   64,   82,  202,  173,
#                  3,    9,  106,   42,   10,    7,   31,    1,  150,   70,  201,
# ...

# %%
!  pip install mysql-connector-python
# Out:
# ...
#      ---------------------------------------- 7.7/7.7 MB 1.2 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\preeti\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install --upgrade pip
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 1.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.3
#     Uninstalling pip-22.0.3:
#       Successfully uninstalled pip-22.0.3
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Preeti\\AppData\\Local\\Temp\\pip-uninstall-x4s_v7f3\\pip.exe'
# Consider using the `--user` option or check the permissions.

# %%
import mysql.connector as sql
mydb = sql.connect(
  host="localhost",
  user="root",
  password=""
)
mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE ingredientdb")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# c:\users\preeti\appdata\local\programs\python\python39\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     508             self.sock.settimeout(self._connection_timeout)
# --> 509             self.sock.connect(sockaddr)
#     510         except IOError as err:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7028/1140948989.py in <module>
#       1 import mysql.connector as sql
# ----> 2 mydb = sql.connect(
#       3   host="localhost",
#       4   user="root",
#       5   password=""
#
# ...

# %%
mydb = sql.connect(
  host="localhost",
  user="root",
  password="",
  database="ingredientdb"
)

# %%
arr= data["ingredients"]
print(len(arr))
for j in range(len(arr)):    
    arr[j] = "_".join(list(arr[j].split()))
    print(arr[j])
# Out:
# 3500
# salt
# pepper
# butter
# garlic
# sugar
# flour
# onion
# olive_oil
# water
# ground
# olive
# powder
# sliced
# eggs
# black_pepper
# milk
# cheese
# cream
# lemon
# chicken
# sauce
# tomatoes
# brown
# white
# egg
# onions
# vinegar
# vegetable
# brown_sugar
# lemon_juice
# ground_black_pepper
# parsley
# cinnamon
# garlic_cloves
# extract
# vegetable_oil
# vanilla
# baking_powder
# vanilla_extract
# unsalted_butter
# ginger
# chocolate
# leaves
# soda
# parmesan
# tomato
# celery
# potatoes
# kosher_salt
# mustard
# cheddar
# juice
# baking_soda
# kosher
# sour_cream
# cilantro
# soy_sauce
# cream_cheese
# parmesan_cheese
# cheddar_cheese
# oregano
# red_pepper
# carrots
# clove
# chicken_broth
# mushrooms
# honey
# packed
# orange
# bread
# thyme
# oil
# basil
# seasoning
# extra
# margarine
# mayonnaise
# bell_pepper
# cayenne
# garlic_powder
# nutmeg
# plus
# cloves
# garlic_minced
# white_wine
# bacon
# peppers
# ground_cinnamon
# heavy_cream
# boneless
# garnish
# ...

# %%
mycursor = mydb.cursor()
query = "CREATE TABLE FOOD ( recipe VARCHAR(150) PRIMARY KEY"
for i in arr:
    if " " in i:
        query+=f",\"{i}\" INT"
    else:
        query+= f",{i} INT"
query+=");"
query
# Out:
# 'CREATE TABLE FOOD ( recipe VARCHAR(150) PRIMARY KEY,salt INT,pepper INT,butter INT,garlic INT,sugar INT,flour INT,onion INT,olive_oil INT,water INT,ground INT,olive INT,powder INT,sliced INT,eggs INT,black_pepper INT,milk INT,cheese INT,cream INT,lemon INT,chicken INT,sauce INT,tomatoes INT,brown INT,white INT,egg INT,onions INT,vinegar INT,vegetable INT,brown_sugar INT,lemon_juice INT,ground_black_pepper INT,parsley INT,cinnamon INT,garlic_cloves INT,extract INT,vegetable_oil INT,vanilla INT,baking_powder INT,vanilla_extract INT,unsalted_butter INT,ginger INT,chocolate INT,leaves INT,soda INT,parmesan INT,tomato INT,celery INT,potatoes INT,kosher_salt INT,mustard INT,cheddar INT,juice INT,baking_soda INT,kosher INT,sour_cream INT,cilantro INT,soy_sauce INT,cream_cheese INT,parmesan_cheese INT,cheddar_cheese INT,oregano INT,red_pepper INT,carrots INT,clove INT,chicken_broth INT,mushrooms INT,honey INT,packed INT,orange INT,bread INT,thyme INT,oil INT,basil INT,seasoning INT,extra IN
# ...

# %%
mycursor.execute(query)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# c:\users\preeti\appdata\local\programs\python\python39\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     534                 query = query.encode('utf-8')
# --> 535             self._cmysql.query(query,
#     536                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'all-purpose_flour INT,icing_sugar INT,flat_leaf_parsley INT,soup INT,splenda INT' at line 1
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17068/3327852350.py in <module>
# ----> 1 mycursor.execute(query)
#
# ...

# %%
mycursor = mydb.cursor()
mycursor.execute("CREATE DATABASE test")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7028/2156351300.py in <module>
# ----> 1 mycursor = mydb.cursor()
#       2 mycursor.execute("CREATE DATABASE test")
#
# NameError: name 'mydb' is not defined
